# %%
Train_path = 'H:\Train'
Cafe_path = 'H:\Cafe'
Hospital_path = 'H:\Hospital'
Bank_path = 'H:\Bank'

# %%
from Sign import SignDataAnalysis, Preprocessing, Generator, Train_models

# %% [markdown]
# # TRAIN CATEGORY

# %%
Train_analysis = SignDataAnalysis(Train_path, 90)
Train_count_DF = Train_analysis.get_paths()
Train_count_DF
# Out:
# Number of classes in Train: 71
#
# Number of samples in each class:
#                      Class Number of Videos                      Class Number of Videos
#                     adress              100                   Mansoura               97
#                      after               98              Marsa Matrouh               98
#                 Alexandria               97                         me              100
#                        and              100                      Minya               99
#                      Aswan              100                      money              100
#                      Asyut               97                         my              100
#                      Banha               96                       name               99
#                 Bani Sweif              100                       need               99
#                    because               96                        new              100
# ...

# %%
Train_count_dic, Train_dataset_DF = Train_analysis.count_frames_in_videos()
Train_dataset_DF
# Out:
# Number of all videos: 6971
# Number of samples will be skipped: 396
#
# Number of videos involved in training 'less than 90 frames' :
#                      Class Count                      Class Count
#                     adress    84                   Mansoura    97
#                      after    98              Marsa Matrouh    98
#                 Alexandria    97                         me   100
#                        and   100                      Minya    99
#                      Aswan   100                      money    82
#                      Asyut    97                         my    82
#                      Banha    96                       name    99
#                 Bani Sweif   100                       need    81
#                    because    96                        new    82
#                     before    97                     number    80
#          birth certificate    82                         ok    82
# ...

# %%
Train_analysis.plot_dict(Train_count_dic)

# %% [markdown]
# # CAFE

# %%
Cafe_analysis = SignDataAnalysis(Cafe_path, 90)
Cafe_count_DF = Cafe_analysis.get_paths()
Cafe_count_DF
# Out:
# Number of classes in Cafe: 54
#
# Number of samples in each class:
#               Class  Number of Videos                 Class  Number of Videos
#              adress               100                 money               100
#                 and               100                    my               100
#               anise                98                  name                99
#              banana                97                  need                99
#              berell                98               nescafe               100
#   birth certificate                98                   new               100
#            cinnamon               100                    no               100
#              coffee                94                number                97
#                cold                98                    ok               100
#                deaf               100                    on               100
# ...

# %%
Cafe_count_dic, Cafe_dataset_DF = Cafe_analysis.count_frames_in_videos()
Cafe_dataset_DF
# Out:
# Number of all videos: 5327
# Number of samples will be skipped: 337
#
# Number of videos involved in training 'less than 90 frames' :
#               Class  Count                 Class  Count
#              adress     84                 money     82
#                 and    100                    my     82
#               anise     98                  name     99
#              banana     97                  need     81
#              berell     98               nescafe    100
#   birth certificate     82                   new     82
#            cinnamon    100                    no    100
#              coffee     94                number     80
#                cold     98                    ok     82
#                deaf    100                    on     82
#               doing     82                    or     80
#               drink     94                orange     98
#           fenugreek     94                 pepsi     98
# ...

# %%
Cafe_analysis.plot_dict(Cafe_count_dic)

# %% [markdown]
# # HOSPITAL

# %%
Hospital_analysis = SignDataAnalysis(Hospital_path, 90)
Hospital_count_DF = Hospital_analysis.get_paths()
Hospital_count_DF
# Out:
# Number of classes in Hospital: 102
#
# Number of samples in each class:
#                      Class  Number of Videos                      Class  Number of Videos
#                     adress               100                       mask                97
#                   analysis                98                         me               100
#                        and               100                      model                98
#                     Anemia                97                      money               100
#               appendicitis                98                         my               100
#                    because                96                       name                99
#                      birth                98                       need                99
#          birth certificate                98                     nerves                97
#                      blood                97                        new               100
# ...

# %%
Hospital_count_dic, Hospital_dataset_DF = Hospital_analysis.count_frames_in_videos()
Hospital_dataset_DF
# Out:
# Number of all videos: 10023
# Number of samples will be skipped: 398
#
# Number of videos involved in training 'less than 90 frames' :
#                      Class  Count                      Class  Count
#                     adress     84                       mask     97
#                   analysis     98                         me    100
#                        and    100                      model     98
#                     Anemia     97                      money     82
#               appendicitis     98                         my     82
#                    because     96                       name     99
#                      birth     98                       need     81
#          birth certificate     82                     nerves     97
#                      blood     97                        new     82
#                      bones     97                     number     80
#                      brain     97                      nusre     98
# ...

# %%
Hospital_analysis.plot_dict(Hospital_count_dic)

# %% [markdown]
# # BANK

# %%
Bank_analysis = SignDataAnalysis(Bank_path, 90)
Bank_count_DF = Bank_analysis.get_paths()
Bank_count_DF
# Out:
# Number of classes in Bank: 72
#
# Number of samples in each class:
#                Class  Number of Videos                      Class  Number of Videos
#              account               100            monthly payment               100
#               adress               100                         my               100
#                  and               100                       name                99
#            apartment               100                       need                99
#        authorization               100                        new               100
#                 Bank               100                     number                97
#         Bank manager                99                         ok               100
#    birth certificate                98                         on               100
#               branch                99                       open               100
# ...

# %%
Bank_count_dic, Bank_dataset_DF = Bank_analysis.count_frames_in_videos()
Bank_dataset_DF
# Out:
# Number of all videos: 7157
# Number of samples will be skipped: 1129
#
# Number of videos involved in training 'less than 90 frames' :
#                Class  Count                      Class  Count
#              account     84            monthly payment     80
#               adress     84                         my     82
#                  and    100                       name     99
#            apartment     82                       need     81
#        authorization     80                        new     82
#                 Bank     84                     number     80
#         Bank manager     81                         ok     82
#    birth certificate     82                         on     82
#               branch     79                       open     80
#                Cairo     96                         or     80
#             changing     80                  ownership     80
#           conditions     82                    pension     80
# ...

# %%
Bank_analysis.plot_dict(Bank_count_dic)
